# %% [markdown]
# ### Mongo Operation

# %%
from pymongo import MongoClient

from contextlib import contextmanager
import pandas as pd

@contextmanager
def connect_mongodb(username : str, password : str, host : str ,port : str):
    uri = f"mongodb://{username}:{password}@{host}:{port}"
    client  = None
    try:
        print("Connecting to MongoDB")
        client = MongoClient(uri)
        print("Connect to MongoDB")
        yield client
    except Exception as e:
        print(f"Error: {e}")
    finally:
        if client:
            client.close()
            print("Stop Connect to MongoDB")
        else:
            print("Can't generate MongoDB Client")
        
class MongoDB_Operation:
    def __init__(self, client):
        """Initialize MongoDB connection."""
        if not isinstance(client, MongoClient):
            raise TypeError("client must be an instance of MongoClient")
        self.client = client

    def check_database_exists(self, db_name):
        """Check if a database exists."""
        return db_name in self.client.list_database_names()

    def check_collection_exists(self, db_name, collection_name):
        """Check if a collection exists in a database."""
        return collection_name in self.client[db_name].list_collection_names()

    def create_database(self, db_name):
        """Create a database if it does not exist."""
        if self.check_database_exists(db_name):
            print(f"Database '{db_name}' already exists!")
            return self.client[db_name]
        else:
            self.client[db_name].command("ping")
            print(f"Database '{db_name}' has been created successfully.")
            return self.client[db_name]
            
    def create_collection(self, db_name, collection_name):
        """Create a collection if it does not exist."""

        db = self.create_database(db_name)

        if self.check_collection_exists(db_name, collection_name):
            print(f"Collection '{collection_name}' already exists!")
            return db[collection_name]
        else:
            db.create_collection(collection_name)
            print(f"Collection '{collection_name}' has been created successfully.")
            return db[collection_name]

    def find_data(self, db_name, collection_name, query=None):
        """Find data in a collection."""
        if not isinstance(query, dict):
            raise TypeError("Query must be a dictionary")
        if not self.check_database_exists(db_name):
            print(f"Database '{db_name}' does not exist!")
        if not self.check_collection_exists(db_name, collection_name):
            print(f"Collection '{collection_name}' does not exist!")

        query = query or {}
        data = self.client[db_name][collection_name].find(query)
        return pd.DataFrame(data)

    def insert_many(self, db_name, collection_name, data : pd.DataFrame):
        """Insert multiple records into a collection."""
        if not isinstance(data, pd.DataFrame):
            raise TypeError("Data must be a Pandas DataFrame")
        
        coll = self.create_collection(db_name=db_name, collection_name=collection_name)

        data_dict = data.to_dict(orient='records')

        if data_dict:
            coll.insert_many(data_dict)
            print("Data has been added successfully.")
        else:
            print("Empty data, nothing to insert.")

# %%
import requests
import pandas as pd

API_KEY = "2d6e1b290dabf74f65b84431677db2b8"
GET_URL = "https://api.themoviedb.org/3/movie/popular"  # URL để lấy danh sách phim phổ biến

def get_movie_name(API_KEY, URL, pages = 10):
    
    list_movies = []  # Danh sách chứa các phim
    for page in range(1, pages + 1):

        # Tạo URL với API_KEY và số trang
        url = f'{URL}?api_key={API_KEY}&language=en-US&page={page}'
        response = requests.get(url)
        data = response.json()

        # Kiểm tra mã trạng thái của phản hồi
        if response.status_code == 200:
            results = data.get('results', [])
            for movie in results:
                title = movie.get('title')
                id = movie.get('id')
                if title:
                    list_movies.append([title, id])
                    print(f"Getting: Title: {title}, ID: {id}")
        else:
            print(f"Error: {data.get('status_message', 'Unknown error')}")
            break
        
    print(f"Total movies: {len(list_movies)}")
    return pd.DataFrame(list_movies, columns=['title', 'id'])

# %%
API_KEY = "2d6e1b290dabf74f65b84431677db2b8"
GET_URL = "https://api.themoviedb.org/3/movie/popular"

client = connect_mongodb(username="ndtien_mongo",
                         password="ndtien_mongo",
                         host="mongodb",
                         port="27017")

with client as mongo_client:
    db_operation = MongoDB_Operation(mongo_client)
    
    # Database and collection names
    db_name = "movies_db"
    collection_name = "movies_name"
    
    # Create database and collection
    db_operation.create_database(db_name)
    db_operation.create_collection(db_name, collection_name)
    
    # Insert data
    data = get_movie_name(API_KEY, GET_URL, pages = 20)
    db_operation.insert_many(db_name, collection_name, data)
# Out:
# Connecting to MongoDB
# Connect to MongoDB
# Database 'movies_db' already exists!
# Database 'movies_db' already exists!
# Collection 'movies_name' already exists!
# Getting: Title: Carjackers, ID: 1229730
# Getting: Title: Cleaner, ID: 1125899
# Getting: Title: The Quiet Ones, ID: 1261050
# Getting: Title: A Working Man, ID: 1197306
# Getting: Title: Captain America: Brave New World, ID: 822119
# Getting: Title: A Minecraft Movie, ID: 950387
# Getting: Title: Cosmic Chaos, ID: 1165067
# Getting: Title: The Codes of War, ID: 1373723
# Getting: Title: Ask Me What You Want, ID: 1252309
# Getting: Title: Peter Pan's Neverland Nightmare, ID: 1020414
# Getting: Title: Popeye the Slayer Man, ID: 1388366
# Getting: Title: Mufasa: The Lion King, ID: 762509
# Getting: Title: Snow White, ID: 447273
# Getting: Title: Holland, ID: 257094
# Getting: Title: The Life List, ID: 1254786
# Getting: Title: Moana 2, ID: 1241982
# Getting: Title: Black Bag, ID: 1233575
# Getting: Title: Sonic the Hedgehog 3, ID: 939243
# Getting: Title: Counterattack, ID: 1356039
# Getting: Title: Flight Risk, ID: 1126166
# Getting: Title: Batman Ninja vs. Yakuza League, ID: 1297763
# Getting: Title: Mickey 17, ID: 696506
# Getting: Title: The Gorge, ID: 950396
# Getting: Title: Z Zone, ID: 1301650
# Getting: Title: Final Twist, ID: 1441734
# Getting: Title: Demon City, ID: 1405338
# Getting: Title: Fight or Flight, ID: 1212855
# Getting: Title: Old Guy, ID: 1077782
# Getting: Title: Kraven the Hunter, ID: 539972
# Getting: Title: Hellhound, ID: 1217379
# Getting: Title: Companion, ID: 1084199
# Getting: Title: Frogman, ID: 1139937
# Getting: Title: Amaran, ID: 927342
# Getting: Title: Sky Force, ID: 1143407
# Getting: Title: Venom: The Last Dance, ID: 912649
# Getting: Title: Dark Match, ID: 1062276
# Getting: Title: Mar.IA, ID: 912032
# Getting: Title: The Electric State, ID: 777443
# Getting: Title: I, the Executioner, ID: 995926
# Getting: Title: Plankton: The Movie, ID: 1104845
# Getting: Title: Opus, ID: 1202479
# Getting: Title: The Vigilante, ID: 1151470
# Getting: Title: Flow, ID: 823219
# Getting: Title: Gladiator II, ID: 558449
# Getting: Title: Solo Leveling -ReAwakening-, ID: 1357633
# Getting: Title: Memoir of a Snail, ID: 1064486
# Getting: Title: Deadpool & Wolverine, ID: 533535
# Getting: Title: Panda Plan, ID: 1160956
# Getting: Title: The Monkey, ID: 1124620
# Getting: Title: Despicable Me 4, ID: 519182
# Getting: Title: Blade Runner 2049, ID: 335984
# Getting: Title: xXx, ID: 7451
# Getting: Title: My Fault, ID: 1010581
# Getting: Title: The Godfather, ID: 238
# Getting: Title: Anora, ID: 1064213
# Getting: Title: Presence, ID: 1140535
# Getting: Title: Henry Danger: The Movie, ID: 926670
# Getting: Title: The Wild Robot, ID: 1184918
# Getting: Title: ¿Quién es quién?, ID: 1187294
# Getting: Title: Inside Out 2, ID: 1022789
# Getting: Title: The Substance, ID: 933260
# Getting: Title: Uppercut, ID: 1391385
# Getting: Title: Los Frikis, ID: 980296
# Getting: Title: Spirited Away, ID: 129
# Getting: Title: Love Hurts, ID: 1226406
# Getting: Title: Banger, ID: 1265623
# Getting: Title: Alarum, ID: 1249289
# Getting: Title: Dog Man, ID: 774370
# Getting: Title: The Shawshank Redemption, ID: 278
# Getting: Title: The Bayou, ID: 1407861
# Getting: Title: Escape, ID: 921436
# Getting: Title: My Fault: London, ID: 1294203
# Getting: Title: Your Fault, ID: 1156593
# Getting: Title: Interstellar, ID: 157336
# Getting: Title: Squad 36, ID: 1230208
# Getting: Title: Control Freak, ID: 1286663
# Getting: Title: Elevation, ID: 1035048
# Getting: Title: Last Breath, ID: 972533
# Getting: Title: Operation Undead, ID: 1244361
# Getting: Title: Avengers: Infinity War, ID: 299536
# Getting: Title: Avengers: Infinity War, ID: 299536
# Getting: Title: Revelations, ID: 1210938
# Getting: Title: Le Clitoris, ID: 426889
# Getting: Title: Bring Them Down, ID: 804862
# Getting: Title: Robotia, la película, ID: 1229646
# Getting: Title: Dalia and the Red Book, ID: 1333099
# Getting: Title: Red One, ID: 845781
# Getting: Title: Groper Train: Touch That Girl, ID: 981044
# Getting: Title: Bloat, ID: 937393
# Getting: Title: Kiskisan, ID: 1337395
# Getting: Title: Wicked, ID: 402431
# Getting: Title: Top Gun: Maverick, ID: 361743
# Getting: Title: 365 Days: This Day, ID: 829557
# Getting: Title: Night Nurse, ID: 58008
# Getting: Title: The Glassworker, ID: 629078
# Getting: Title: Heretic, ID: 1138194
# Getting: Title: Novocaine, ID: 1195506
# Getting: Title: Room in Rome, ID: 48650
# Getting: Title: Schindler's List, ID: 424
# Getting: Title: Scarlet Innocence, ID: 287649
# Getting: Title: Alexander and the Terrible, Horrible, No Good, Very Bad Road Trip, ID: 774100
# Getting: Title: Devara : Part 1, ID: 811941
# Getting: Title: Long Arm of the Law II, ID: 221536
# Getting: Title: Bad Boys: Ride or Die, ID: 573435
# Getting: Title: Absolution, ID: 974453
# Getting: Title: Nosferatu, ID: 426063
# Getting: Title: Pleasure, ID: 592695
# Getting: Title: Anastasia, ID: 1260416
# Getting: Title: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe, ID: 411
# Getting: Title: Back in Action, ID: 993710
# Getting: Title: The Lord of the Rings: The War of the Rohirrim, ID: 839033
# Getting: Title: Sex Education Mistresses, ID: 968171
# Getting: Title: Apocalypse Z: The Beginning of the End, ID: 1118031
# Getting: Title: The Dark Knight, ID: 155
# Getting: Title: Fast X, ID: 385687
# Getting: Title: Miraculous World: London, At the Edge of Time, ID: 1147416
# Getting: Title: The Gardener, ID: 1255788
# Getting: Title: María, ¡Me muero!, ID: 1360170
# Getting: Title: Final Destination Bloodlines, ID: 574475
# Getting: Title: Piglet, ID: 1352774
# Getting: Title: Harry Potter and the Philosopher's Stone, ID: 671
# Getting: Title: Sniper: The Last Stand, ID: 1410082
# Getting: Title: Terrifier 3, ID: 1034541
# Getting: Title: The Curse of the Necklace, ID: 1293263
# Getting: Title: Titanic, ID: 597
# Getting: Title: Paddington in Peru, ID: 516729
# Getting: Title: Lembayung, ID: 1164355
# Getting: Title: Tatsulok, ID: 1357459
# Getting: Title: Chijin no Ai, ID: 1395724
# Getting: Title: Smile 2, ID: 1100782
# Getting: Title: OVERLORD: The Sacred Kingdom, ID: 1014505
# Getting: Title: Attack on Titan: THE LAST ATTACK, ID: 1333100
# Getting: Title: Mesa de regalos, ID: 1302151
# Getting: Title: Wonder Woman, ID: 297762
# Getting: Title: Never Let Go, ID: 814889
# Getting: Title: Spider-Man: No Way Home, ID: 634649
# Getting: Title: Tyler Perry's Duplicity, ID: 1145725
# Getting: Title: Ellie and the Monster Team, ID: 1217876
# Getting: Title: The Avengers, ID: 24428
# Getting: Title: Victoria, ID: 653794
# Getting: Title: The Parenting, ID: 850920
# Getting: Title: Con Mum, ID: 1442440
# Getting: Title: Fight Club, ID: 550
# Getting: Title: Chuck Billy and The Marvelous Guava Tree, ID: 935766
# Getting: Title: Babygirl, ID: 1097549
# Getting: Title: Winner, ID: 1039659
# Getting: Title: Ne Zha 2, ID: 980477
# Getting: Title: Wolf Man, ID: 710295
# Getting: Title: Godzilla x Kong: The New Empire, ID: 823464
# Getting: Title: Shrek, ID: 808
# Getting: Title: Alien: Romulus, ID: 945961
# Getting: Title: John Wick: Chapter 4, ID: 603692
# Getting: Title: Howl's Moving Castle, ID: 4935
# Getting: Title: Spider-Man: Across the Spider-Verse, ID: 569094
# Getting: Title: Ne Zha, ID: 615453
# Getting: Title: Werewolves, ID: 970450
# Getting: Title: The X-Treme Riders, ID: 1188104
# Getting: Title: Dead Talents Society, ID: 1006724
# Getting: Title: Kong: Skull Island, ID: 293167
# Getting: Title: Gladiator, ID: 98
# Getting: Title: The Matrix, ID: 603
# Getting: Title: Promised Hearts, ID: 1261555
# Getting: Title: Conclave, ID: 974576
# Getting: Title: Avatar, ID: 19995
# Getting: Title: Harry Potter and the Goblet of Fire, ID: 674
# Getting: Title: Oppenheimer, ID: 872585
# Getting: Title: The Island, ID: 1138749
# Getting: Title: Kung Fu Panda 4, ID: 1011985
# Getting: Title: The Godfather Part II, ID: 240
# Getting: Title: Girl Play, ID: 85430
# Getting: Title: Dune, ID: 438631
# Getting: Title: Dune: Part Two, ID: 693134
# Getting: Title: Inception, ID: 27205
# Getting: Title: The Lord of the Rings: The Return of the King, ID: 122
# Getting: Title: The Lord of the Rings: The Fellowship of the Ring, ID: 120
# Getting: Title: Dirty Angels, ID: 1043905
# Getting: Title: The Lion King, ID: 420818
# Getting: Title: The Maze Runner, ID: 198663
# Getting: Title: The Cousin, ID: 253350
# Getting: Title: Death Whisperer 2, ID: 1247019
# Getting: Title: Parthenope, ID: 1109255
# Getting: Title: Night Call, ID: 1001274
# Getting: Title: Transformers One, ID: 698687
# Getting: Title: Shark Girl, ID: 1316673
# Getting: Title: Barbie, ID: 346698
# Getting: Title: Twilight, ID: 8966
# Getting: Title: Harry Potter and the Chamber of Secrets, ID: 672
# Getting: Title: The Brutalist, ID: 549509
# Getting: Title: Coraline, ID: 14836
# Getting: Title: Inside Out, ID: 150540
# Getting: Title: Den of Thieves 2: Pantera, ID: 604685
# Getting: Title: Avatar: The Way of Water, ID: 76600
# Getting: Title: Lilo & Stitch, ID: 11544
# Getting: Title: Coco, ID: 354912
# Getting: Title: Top Gun, ID: 744
# Getting: Title: The Super Mario Bros. Movie, ID: 502356
# Getting: Title: Azrael, ID: 1029235
# Getting: Title: Sidelined: The QB and Me, ID: 957119
# Getting: Title: The Amateur, ID: 1087891
# Getting: Title: Baby Face, ID: 27449
# Getting: Title: Fifty Shades of Grey, ID: 216015
# Getting: Title: Final Destination, ID: 9532
# Getting: Title: The Beekeeper, ID: 866398
# Getting: Title: Snow White and the Seven Dwarfs, ID: 408
# Getting: Title: Harry Potter and the Prisoner of Azkaban, ID: 673
# Getting: Title: The Conjuring, ID: 138843
# Getting: Title: Heat, ID: 949
# Getting: Title: Pulp Fiction, ID: 680
# Getting: Title: Puri for Rent, ID: 1450436
# Getting: Title: Parasite, ID: 496243
# Getting: Title: Borderline, ID: 1013482
# Getting: Title: Furiosa: A Mad Max Saga, ID: 786892
# Getting: Title: Deva, ID: 1195430
# Getting: Title: Carry-On, ID: 1005331
# Getting: Title: Hotel Desire, ID: 82023
# Getting: Title: Little Siberia, ID: 1362608
# Getting: Title: A Quiet Place: Day One, ID: 762441
# Getting: Title: The Garfield Movie, ID: 748783
# Getting: Title: The Batman, ID: 414906
# Getting: Title: The Lion King, ID: 8587
# Getting: Title: Kingdom of the Planet of the Apes, ID: 653346
# Getting: Title: Pirates of the Caribbean: The Curse of the Black Pearl, ID: 22
# Getting: Title: Toy Story, ID: 862
# Getting: Title: Sonic the Hedgehog 2, ID: 675353
# Getting: Title: Dhoom Dhaam, ID: 1201012
# Getting: Title: Your Name., ID: 372058
# Getting: Title: Fifty Shades Freed, ID: 337167
# Getting: Title: Arcadian, ID: 1051896
# Getting: Title: Spider-Man: Into the Spider-Verse, ID: 324857
# Getting: Title: Puss in Boots: The Last Wish, ID: 315162
# Getting: Title: Harry Potter and the Deathly Hallows: Part 1, ID: 12444
# Getting: Title: Paprika, ID: 50270
# Getting: Title: Forrest Gump, ID: 13
# Getting: Title: The Equalizer, ID: 156022
# Getting: Title: Rita, ID: 1241752
# Getting: Title: Harry Potter and the Deathly Hallows: Part 2, ID: 12445
# Getting: Title: 28 Days Later, ID: 170
# Getting: Title: Avengers: Endgame, ID: 299534
# Getting: Title: Wrath of Man, ID: 637649
# Getting: Title: The Wolf of Wall Street, ID: 106646
# Getting: Title: Laila, ID: 1403735
# Getting: Title: Bagman, ID: 978796
# Getting: Title: Jugaremos en el bosque, ID: 1249013
# Getting: Title: After, ID: 537915
# Getting: Title: Migration, ID: 940551
# Getting: Title: Alone In The Night, ID: 1244881
# Getting: Title: Big Hero 6, ID: 177572
# Getting: Title: Transformers: Rise of the Beasts, ID: 667538
# Getting: Title: Below Her Mouth, ID: 370663
# Getting: Title: Spider-Man, ID: 557
# Getting: Title: My Neighbor Totoro, ID: 8392
# Getting: Title: Shrek 2, ID: 809
# Getting: Title: Aftermath, ID: 1081012
# Getting: Title: Mission: Impossible - Dead Reckoning Part One, ID: 575264
# Getting: Title: Flies, ID: 1177908
# Getting: Title: Lilo & Stitch, ID: 552524
# Getting: Title: Se7en, ID: 807
# Getting: Title: Avengers: Doomsday, ID: 1003596
# Getting: Title: Frozen, ID: 109445
# Getting: Title: Spin the Bottle, ID: 1030983
# Getting: Title: Ratatouille, ID: 2062
# Getting: Title: The Lord of the Rings: The Two Towers, ID: 121
# Getting: Title: Five Nights at Freddy's, ID: 507089
# Getting: Title: Kingdom IV: Return of the Great General, ID: 1241320
# Getting: Title: Better Man, ID: 799766
# Getting: Title: Female Teacher Closing the Door, ID: 1055110
# Getting: Title: Armor, ID: 1182387
# Getting: Title: Zootopia, ID: 269149
# Getting: Title: Tangled, ID: 38757
# Getting: Title: The Boy and the Heron, ID: 508883
# Getting: Title: Harry Potter and the Order of the Phoenix, ID: 675
# Getting: Title: Fury, ID: 228150
# Getting: Title: Finding Nemo, ID: 12
# Getting: Title: Tombstone, ID: 11969
# Getting: Title: Feast of the Fallen Angels, ID: 1209794
# Getting: Title: IF, ID: 639720
# Getting: Title: Deva, ID: 1447439
# Getting: Title: The Notebook, ID: 11036
# Getting: Title: Den of Thieves, ID: 449443
# Getting: Title: Avengers: Age of Ultron, ID: 99861
# Getting: Title: Sikandar, ID: 1257960
# Getting: Title: Godzilla Minus One, ID: 940721
# Getting: Title: Toy Story 2, ID: 863
# Getting: Title: The Twilight Saga: Breaking Dawn - Part 2, ID: 50620
# Getting: Title: Beauty and the Beast, ID: 321612
# Getting: Title: Elemental, ID: 976573
# Getting: Title: The Green Mile, ID: 497
# Getting: Title: Mad Max: Fury Road, ID: 76341
# Getting: Title: Joker, ID: 475557
# Getting: Title: I'm Still Here, ID: 1000837
# Getting: Title: A Complete Unknown, ID: 661539
# Getting: Title: Abigail, ID: 1111873
# Getting: Title: Wallace & Gromit: Vengeance Most Fowl, ID: 929204
# Getting: Title: Friendship, ID: 1239655
# Getting: Title: Eye for an Eye 2, ID: 1235623
# Getting: Title: Final Destination 5, ID: 55779
# Getting: Title: Pabrik Gula, ID: 1355126
# Getting: Title: Spider-Man: Homecoming, ID: 315635
# Getting: Title: Civil War, ID: 929590
# Getting: Title: Doctor Strange in the Multiverse of Madness, ID: 453395
# Getting: Title: Doctor Strange in the Multiverse of Madness, ID: 453395
# Getting: Title: Iron Man, ID: 1726
# Getting: Title: Friendly Police, ID: 928228
# Getting: Title: Survive, ID: 1196470
# Getting: Title: Anatema, ID: 1104390
# Getting: Title: Whisper of the Witch, ID: 1100856
# Getting: Title: Poor Things, ID: 792307
# Getting: Title: Black Panther, ID: 284054
# Getting: Title: Niko: Beyond the Northern Lights, ID: 717196
# Getting: Title: Black Panther: Wakanda Forever, ID: 505642
# Getting: Title: The Crow, ID: 957452
# Getting: Title: River of Blood, ID: 1222064
# Getting: Title: Death of a Unicorn, ID: 1153714
# Getting: Title: Monsters, Inc., ID: 585
# Getting: Title: 12 Angry Men, ID: 389
# Getting: Title: Shutter Island, ID: 11324
# Getting: Title: Black Widow, ID: 497698
# Getting: Title: Dispassionate Love, ID: 617359
# Getting: Title: Whiplash, ID: 244786
# Getting: Title: Venom, ID: 335983
# Getting: Title: Captain America: Civil War, ID: 271110
# Getting: Title: Final Destination 2, ID: 9358
# Getting: Title: Train to Busan, ID: 396535
# Getting: Title: Skin. Like. Sun., ID: 259872
# Getting: Title: Guardians of the Galaxy Vol. 3, ID: 447365
# Getting: Title: Harry Potter and the Half-Blood Prince, ID: 767
# Getting: Title: The Truman Show, ID: 37165
# Getting: Title: Star Wars, ID: 11
# Getting: Title: Encanto, ID: 568124
# Getting: Title: Las corredoras, ID: 1249454
# Getting: Title: Jurassic World, ID: 135397
# Getting: Title: Snowpiercer, ID: 110415
# Getting: Title: Glossary of Non-Human Love, ID: 830926
# Getting: Title: Anyone But You, ID: 1072790
# Getting: Title: Fast X: Part 2, ID: 755679
# Getting: Title: Gone Girl, ID: 210577
# Getting: Title: John Wick, ID: 245891
# Getting: Title: Dogman, ID: 944401
# Getting: Title: MANUEL, ID: 1052243
# Getting: Title: Thunderbolts*, ID: 986056
# Getting: Title: Blue Lights, ID: 1229873
# Getting: Title: Alien, ID: 348
# Getting: Title: Princess Mononoke, ID: 128
# Getting: Title: L2: Empuraan, ID: 627336
# Getting: Title: The Passion of the Christ, ID: 615
# Getting: Title: Bridget Jones: Mad About the Boy, ID: 1272149
# Getting: Title: The Handmaiden, ID: 290098
# Getting: Title: The Twister: Caught in the Storm, ID: 1437446
# Getting: Title: Terminator 2: Judgment Day, ID: 280
# Getting: Title: Bad Influence, ID: 1323784
# Getting: Title: The Hobbit: The Battle of the Five Armies, ID: 122917
# Getting: Title: Pirates of the Caribbean: Dead Man's Chest, ID: 58
# Getting: Title: The Equalizer 3, ID: 926393
# Getting: Title: Hereditary, ID: 493922
# Getting: Title: Saving Private Ryan, ID: 857
# Getting: Title: Love Rites, ID: 195223
# Getting: Title: Speak No Evil, ID: 1114513
# Getting: Title: Winnie-the-Pooh: Blood and Honey 2, ID: 1079485
# Getting: Title: Ice Age, ID: 425
# Getting: Title: Female Workers: Romance at Work 3, ID: 1231914
# Getting: Title: Subservience, ID: 1064028
# Getting: Title: Iron Man 2, ID: 10138
# Getting: Title: Sonic the Hedgehog, ID: 454626
# Getting: Title: One of Them Days, ID: 1280672
# Getting: Title: Cinderella, ID: 150689
# Getting: Title: Road House, ID: 359410
# Getting: Title: Shrek the Third, ID: 810
# Getting: Title: Freestyle, ID: 892494
# Getting: Title: Jurassic World Dominion, ID: 507086
# Getting: Title: Fast & Furious Presents: Hobbs & Shaw, ID: 384018
# Getting: Title: Bird, ID: 1128752
# Getting: Title: The Next 365 Days, ID: 829560
# Getting: Title: Crazy Desire, ID: 116236
# Getting: Title: Tarot, ID: 719221
# Getting: Title: Jumanji: Welcome to the Jungle, ID: 353486
# Getting: Title: Girl in the Basement, ID: 801335
# Getting: Title: The Count of Monte Cristo, ID: 1084736
# Getting: Title: Levels, ID: 791042
# Getting: Title: Beauty and the Beast, ID: 10020
# Getting: Title: The Terminator, ID: 218
# Getting: Title: Pirates of the Caribbean: On Stranger Tides, ID: 1865
# Getting: Title: Mission: Impossible - The Final Reckoning, ID: 575265
# Getting: Title: Twisters, ID: 718821
# Getting: Title: The Little Mermaid, ID: 447277
# Getting: Title: Thor: Ragnarok, ID: 284053
# Getting: Title: Deadpool, ID: 293660
# Getting: Title: Up, ID: 14160
# Getting: Title: The Saint, ID: 10003
# Getting: Title: Delinquent in Drag, ID: 324568
# Getting: Title: Captain Marvel, ID: 299537
# Getting: Title: Scarface, ID: 111
# Getting: Title: La La Land, ID: 313369
# Getting: Title: xXx: Return of Xander Cage, ID: 47971
# Getting: Title: Prisoners, ID: 146233
# Getting: Title: My Hero Academia: You're Next, ID: 1159311
# Getting: Title: Boreal, ID: 1379074
# Getting: Title: World War Z, ID: 72190
# Getting: Title: The Price of Money: A Largo Winch Adventure, ID: 1000075
# Getting: Title: Hidden Figures, ID: 381284
# Getting: Title: GoodFellas, ID: 769
# Total movies: 400
# Database 'movies_db' already exists!
# Collection 'movies_name' already exists!
# Data has been added successfully.
# Stop Connect to MongoDB
